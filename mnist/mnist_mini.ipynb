# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# mnist_train = pd.read_csv('/content/drive/My Drive/SKinfosec/mnist/mnist_train.csv')
# mnist_test = pd.read_csv('/content/drive/My Drive/SKinfosec/mnist/mnist_test.csv')
# mnist_train_100 = pd.read_csv('/content/drive/My Drive/SKinfosec/mnist/mnist_train_100.csv')
# mnist_test_10 = pd.read_csv('/content/drive/My Drive/SKinfosec/mnist/mnist_test_10.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt

data_file = open('mnist_test_10.csv', 'r')
data_list = data_file.readlines()
data_file.close()


all_values = data_list[i].split(',')
image_array = np.asfarray(all_values[1:]).reshape((28,28))

plt.imshow(image_array, cmap='Greys', interpolation=None)
plt.show()

# %%
for i in range(len(data_list)):
    all_values = data_list[i].split(',')
    image_array = np.asfarray(all_values[1:]).reshape((28,28))
    plt.imshow(image_array, cmap='Greys', interpolation=None)
    plt.show()

# %%
scaled_input = np.asfarray(all_values[1:]) / 255.0 * 0.99 + 0.01 # 모든 값들을 0~1 사이의 수로 변경하기 위해서 scale을 변경한 것이다.
scaled_input
# Out:
# array([0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
#        0.01      , 0.01      , 0.01      , 0.01      , 0.01      ,
# ...
